# %%
# !pip install mlrose-hiive
# %load_ext autoreload
# %autoreload 2
# Out:
# Requirement already satisfied: mlrose-hiive in /usr/local/lib/python3.8/dist-packages (2.2.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from mlrose-hiive) (1.22.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from mlrose-hiive) (2.8.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from mlrose-hiive) (1.5.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from mlrose-hiive) (1.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from mlrose-hiive) (1.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from mlrose-hiive) (1.9.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas->mlrose-hiive) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas->mlrose-hiive) (2022.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->mlrose-hiive) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas->mlrose-hiive) (1.14.0)
# WARNING: You are using pip version 20.2.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
mlr_data = '/tf/data/mlrose/'
mlr_src = '../'
# !ls $mlr_src
# !ls $mlr_data
# Out:
# Constants.py   Graph.py   __pycache__  kcolors	  nqueens
# Experiment.py  README.md  jupyter      notes.txt  tsp
# __pycache__  kcolors  nqueens

# %%
import mlrose_hiive
import numpy as np
from mlrose_hiive import QueensGenerator, MaxKColorGenerator, TSPGenerator
from mlrose_hiive import SARunner, GARunner, NNGSRunner
import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline
import sys
import os


sys.path.insert(0, mlr_src)
from Graph import *
from Experiment import *

# %%
'''
███╗░░██╗  ░██████╗░██╗░░░██╗███████╗███████╗███╗░░██╗░██████╗
████╗░██║  ██╔═══██╗██║░░░██║██╔════╝██╔════╝████╗░██║██╔════╝
██╔██╗██║  ██║██╗██║██║░░░██║█████╗░░█████╗░░██╔██╗██║╚█████╗░
██║╚████║  ╚██████╔╝██║░░░██║██╔══╝░░██╔══╝░░██║╚████║░╚═══██╗
██║░╚███║  ░╚═██╔═╝░╚██████╔╝███████╗███████╗██║░╚███║██████╔╝
╚═╝░░╚══╝  ░░░╚═╝░░░░╚═════╝░╚══════╝╚══════╝╚═╝░░╚══╝╚═════╝░
'''

# !ls $mlr_src/nqueens
# !ls $mlr_data/nqueens
# Out:
# __pycache__  run.py
# pickle_ga.p  pickle_mim.p  pickle_rhc.p  pickle_sa.p

# %%
sa = Experiment.pickle_load(os.path.join(mlr_data, 'nqueens','pickle_sa.p'))
#graph it. 
s = Search()
s.filters.append(TagFilter('q',20))
# s.filters.append(TagFilter('sch','arith','ne'))
graph_generate_single(sa, search=s)

# %%
ga = Experiment.pickle_load(os.path.join(mlr_data, 'nqueens','pickle_ga.p'))
#graph it. 
s = Search()
s.filters.append(TagFilter('q',20))
s.filters.append(TagFilter('minelite',1))
graph_generate_single(ga, search=s)

# %%
mim = Experiment.pickle_load(os.path.join(mlr_data, 'nqueens','pickle_mim.p'))
#graph it. 
s = Search()
s.filters.append(TagFilter('q',20))
graph_generate_single(mim, search=s)

# %%
rhc = Experiment.pickle_load(os.path.join(mlr_data, 'nqueens','pickle_rhc.p'))
#graph it. 
s = Search()
s.filters.append(TagFilter('q',20))
graph_generate_single(rhc, search=s)

# %%
'''
██╗░░██╗  ░█████╗░░█████╗░██╗░░░░░░█████╗░██████╗░
██║░██╔╝  ██╔══██╗██╔══██╗██║░░░░░██╔══██╗██╔══██╗
█████═╝░  ██║░░╚═╝██║░░██║██║░░░░░██║░░██║██████╔╝
██╔═██╗░  ██║░░██╗██║░░██║██║░░░░░██║░░██║██╔══██╗
██║░╚██╗  ╚█████╔╝╚█████╔╝███████╗╚█████╔╝██║░░██║
╚═╝░░╚═╝  ░╚════╝░░╚════╝░╚══════╝░╚════╝░╚═╝░░╚═╝
'''

# !ls $mlr_src/kcolors
# !ls $mlr_data/kcolors
# Out:
# __pycache__  run.py
# pickle_ga.p  pickle_mim.p  pickle_rhc.p  pickle_sa.p

# %%
sa = Experiment.pickle_load(os.path.join(mlr_data, 'kcolors','pickle_sa.p'))
#graph it. 
s = Search()
s.filters.append(TagFilter('n',40))
s.filters.append(TagFilter('sch','geom'))
graph_generate_single(sa, search=s)

# %%
ga = Experiment.pickle_load(os.path.join(mlr_data, 'kcolors','pickle_ga.p'))
#graph it. 
s = Search()
s.filters.append(TagFilter('n',40))
s.filters.append(TagFilter('minelite',1))
graph_generate_single(ga, search=s)

# %%
mim = Experiment.pickle_load(os.path.join(mlr_data, 'kcolors','pickle_mim.p'))
#graph it. 
s = Search()
s.filters.append(TagFilter('n',40))
graph_generate_single(mim, search=s)

# %%
rhc = Experiment.pickle_load(os.path.join(mlr_data, 'kcolors','pickle_rhc.p'))
#graph it. 
s = Search()
s.filters.append(TagFilter('n',40))
graph_generate_single(rhc, search=s)

# %%
'''
░█████╗░███╗░░██╗███████╗  ███╗░░░███╗░█████╗░██╗░░██╗
██╔══██╗████╗░██║██╔════╝  ████╗░████║██╔══██╗╚██╗██╔╝
██║░░██║██╔██╗██║█████╗░░  ██╔████╔██║███████║░╚███╔╝░
██║░░██║██║╚████║██╔══╝░░  ██║╚██╔╝██║██╔══██║░██╔██╗░
╚█████╔╝██║░╚███║███████╗  ██║░╚═╝░██║██║░░██║██╔╝╚██╗
░╚════╝░╚═╝░░╚══╝╚══════╝  ╚═╝░░░░░╚═╝╚═╝░░╚═╝╚═╝░░╚═╝
'''
# !ls $mlr_src/onemax
# !ls $mlr_data/onemax
# Out:
# __pycache__  run.py
# pickle_rhc.p

# %%
sa = Experiment.pickle_load(os.path.join(mlr_data, 'onemax','pickle_sa.p'))
#graph it. 
s = Search()
s.filters.append(TagFilter('size',32))
s.filters.append(TagFilter('sch','geom'))
graph_generate_single(sa, search=s)
sa.results
# Out:
# [sa_size2_scharith_m1000|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  sa_size2_schgeom_m1000|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  sa_size1_scharith_m1000|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  sa_size1_schgeom_m1000|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  sa_size4_scharith_m1000|best_fit:4.0|best_it:2|time_to_best:0.00098|fevals_to_best:6.0|fevals:6.0,
#  sa_size2_schexp_m1000|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  sa_size1_schexp_m1000|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  sa_size16_schgeom_m1000|best_fit:16.0|best_it:48|time_to_best:0.00136|fevals_to_best:75.0|fevals:75.0,
#  sa_size4_schgeom_m1000|best_fit:4.0|best_it:2|time_to_best:9e-05|fevals_to_best:6.0|fevals:6.0,
#  sa_size8_schexp_m1000|best_fit:8.0|best_it:27|time_to_best:0.00126|fevals_to_best:48.0|fevals:48.0,
#  sa_size8_schgeom_m1000|best_fit:8.0|best_it:27|time_to_best:0.0005|fevals_to_best:48.0|fevals:48.0,
#  sa_size8_scharith_m1000|best_fit:8.0|best_it:27|time_to_best:0.00052|fevals_to_best:48.0|fevals:48.0,
#  sa_size4_schexp_m1000|best_fit:4.0|best_it:2|time_to_best:0.00012|fevals_to_best:6.0|fevals:6.0,
#  sa_size16_scharith_m1000|best_fit:16.0|best_it:1095|time_to_best:0.16099|fevals_to_best:1660.0|fevals:1660.0,
#  sa_size16_schexp_m1000|best_fit:16.0|best_it:52|time_to_best:0.00103|fevals_to_best:83.0|fevals:83.0,
#  sa_size32_schgeom_m1000|best_fit:32.0|best_it:264|time_to_best:0.0079|fevals_to_best:311.0|fevals:311.0,
#  sa_size32_schexp_m1000|best_fit:32.0|best_it:343|time_to_best:0.01248|fevals_to_best:412.0|fevals:412.0,
#  sa_size32_scharith_m1000|best_fit:32.0|best_it:5613|time_to_best:2.12035|fevals_to_best:7810.0|fevals:7810.0]

# %%
ga = Experiment.pickle_load(os.path.join(mlr_data, 'onemax','pickle_ga.p'))
#graph it. 
s = Search()
s.filters.append(TagFilter('size',32))
s.filters.append(TagFilter('mut',0.1))
graph_generate_single(ga, search=s)
ga.results
# Out:
# [ga_size1_pop100_m1000_mut0.2_minelite0|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size1_pop200_m1000_mut0.1_minelite0|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size1_pop100_m1000_mut0.1_minelite0|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size1_pop100_m1000_mut0.3_minelite1|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size1_pop100_m1000_mut0.1_minelite1|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size1_pop100_m1000_mut0.3_minelite0|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size1_pop100_m1000_mut0.2_minelite1|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size1_pop200_m1000_mut0.2_minelite1|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size1_pop200_m1000_mut0.1_minelite1|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size1_pop200_m1000_mut0.2_minelite0|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size1_pop400_m1000_mut0.1_minelite0|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size1_pop200_m1000_mut0.3_minelite1|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size1_pop200_m1000_mut0.3_minelite0|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size1_pop400_m1000_mut0.1_minelite1|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size1_pop400_m1000_mut0.2_minelite0|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size1_pop400_m1000_mut0.2_minelite1|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size1_pop400_m1000_mut0.3_minelite1|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size1_pop800_m1000_mut0.1_minelite0|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size1_pop800_m1000_mut0.2_minelite0|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size1_pop400_m1000_mut0.3_minelite0|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size1_pop800_m1000_mut0.1_minelite1|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size1_pop800_m1000_mut0.3_minelite1|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size1_pop800_m1000_mut0.3_minelite0|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size2_pop100_m1000_mut0.2_minelite0|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size1_pop800_m1000_mut0.2_minelite1|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size2_pop100_m1000_mut0.1_minelite0|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size2_pop100_m1000_mut0.2_minelite1|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size2_pop100_m1000_mut0.1_minelite1|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size2_pop100_m1000_mut0.3_minelite1|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size2_pop100_m1000_mut0.3_minelite0|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size2_pop200_m1000_mut0.2_minelite0|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size2_pop200_m1000_mut0.2_minelite1|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size2_pop200_m1000_mut0.1_minelite1|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size2_pop200_m1000_mut0.3_minelite0|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size2_pop200_m1000_mut0.1_minelite0|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size2_pop200_m1000_mut0.3_minelite1|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size2_pop400_m1000_mut0.2_minelite0|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size2_pop400_m1000_mut0.1_minelite0|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size2_pop400_m1000_mut0.2_minelite1|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size2_pop400_m1000_mut0.3_minelite0|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size2_pop400_m1000_mut0.1_minelite1|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size2_pop400_m1000_mut0.3_minelite1|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size2_pop800_m1000_mut0.3_minelite1|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size2_pop800_m1000_mut0.1_minelite0|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size2_pop800_m1000_mut0.2_minelite0|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size2_pop800_m1000_mut0.2_minelite1|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size4_pop100_m1000_mut0.1_minelite0|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size2_pop800_m1000_mut0.1_minelite1|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size2_pop800_m1000_mut0.3_minelite0|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size4_pop100_m1000_mut0.1_minelite1|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size4_pop100_m1000_mut0.2_minelite0|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size4_pop200_m1000_mut0.1_minelite1|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size4_pop100_m1000_mut0.2_minelite1|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size4_pop100_m1000_mut0.3_minelite0|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size4_pop100_m1000_mut0.3_minelite1|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size4_pop200_m1000_mut0.1_minelite0|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size4_pop200_m1000_mut0.2_minelite1|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size4_pop400_m1000_mut0.1_minelite0|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size4_pop200_m1000_mut0.3_minelite0|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size4_pop400_m1000_mut0.2_minelite0|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size4_pop200_m1000_mut0.2_minelite0|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size4_pop200_m1000_mut0.3_minelite1|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size4_pop400_m1000_mut0.1_minelite1|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size4_pop800_m1000_mut0.1_minelite0|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size4_pop800_m1000_mut0.2_minelite1|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size4_pop400_m1000_mut0.2_minelite1|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size4_pop400_m1000_mut0.3_minelite0|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size4_pop800_m1000_mut0.1_minelite1|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size4_pop400_m1000_mut0.3_minelite1|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size4_pop800_m1000_mut0.2_minelite0|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size8_pop100_m1000_mut0.1_minelite1|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size4_pop800_m1000_mut0.3_minelite1|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size8_pop100_m1000_mut0.3_minelite0|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size4_pop800_m1000_mut0.3_minelite0|best_fit:4.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size8_pop100_m1000_mut0.2_minelite1|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size8_pop100_m1000_mut0.1_minelite0|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size8_pop100_m1000_mut0.2_minelite0|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size8_pop200_m1000_mut0.3_minelite0|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size8_pop200_m1000_mut0.2_minelite1|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size8_pop100_m1000_mut0.3_minelite1|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:202.0|fevals:202.0,
#  ga_size8_pop200_m1000_mut0.1_minelite1|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size8_pop200_m1000_mut0.2_minelite0|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size8_pop200_m1000_mut0.3_minelite1|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size8_pop200_m1000_mut0.1_minelite0|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:402.0|fevals:402.0,
#  ga_size8_pop400_m1000_mut0.3_minelite0|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size8_pop400_m1000_mut0.1_minelite1|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size8_pop400_m1000_mut0.2_minelite0|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size8_pop400_m1000_mut0.3_minelite1|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size8_pop400_m1000_mut0.1_minelite0|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size8_pop400_m1000_mut0.2_minelite1|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:802.0|fevals:802.0,
#  ga_size8_pop800_m1000_mut0.1_minelite0|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size8_pop800_m1000_mut0.3_minelite1|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size8_pop800_m1000_mut0.2_minelite1|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size8_pop800_m1000_mut0.2_minelite0|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size16_pop100_m1000_mut0.1_minelite0|best_fit:16.0|best_it:4|time_to_best:0.00789|fevals_to_best:607.0|fevals:607.0,
#  ga_size8_pop800_m1000_mut0.1_minelite1|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size8_pop800_m1000_mut0.3_minelite0|best_fit:8.0|best_it:0|time_to_best:0.0|fevals_to_best:1602.0|fevals:1602.0,
#  ga_size16_pop100_m1000_mut0.1_minelite1|best_fit:16.0|best_it:5|time_to_best:0.0181|fevals_to_best:708.0|fevals:708.0,
#  ga_size16_pop100_m1000_mut0.2_minelite1|best_fit:16.0|best_it:4|time_to_best:0.00744|fevals_to_best:607.0|fevals:607.0,
#  ga_size16_pop200_m1000_mut0.1_minelite0|best_fit:16.0|best_it:4|time_to_best:0.01564|fevals_to_best:1207.0|fevals:1207.0,
#  ga_size16_pop100_m1000_mut0.2_minelite0|best_fit:16.0|best_it:7|time_to_best:0.01577|fevals_to_best:910.0|fevals:910.0,
#  ga_size16_pop200_m1000_mut0.2_minelite0|best_fit:16.0|best_it:3|time_to_best:0.01629|fevals_to_best:1006.0|fevals:1006.0,
#  ga_size16_pop100_m1000_mut0.3_minelite1|best_fit:16.0|best_it:4|time_to_best:0.01004|fevals_to_best:607.0|fevals:607.0,
#  ga_size16_pop100_m1000_mut0.3_minelite0|best_fit:16.0|best_it:5|time_to_best:0.02288|fevals_to_best:708.0|fevals:708.0,
#  ga_size16_pop200_m1000_mut0.1_minelite1|best_fit:16.0|best_it:3|time_to_best:0.01554|fevals_to_best:1006.0|fevals:1006.0,
#  ga_size16_pop200_m1000_mut0.3_minelite1|best_fit:16.0|best_it:4|time_to_best:0.01588|fevals_to_best:1207.0|fevals:1207.0,
#  ga_size16_pop200_m1000_mut0.3_minelite0|best_fit:16.0|best_it:4|time_to_best:0.0162|fevals_to_best:1207.0|fevals:1207.0,
#  ga_size16_pop400_m1000_mut0.2_minelite1|best_fit:16.0|best_it:3|time_to_best:0.0268|fevals_to_best:2006.0|fevals:2006.0,
#  ga_size16_pop200_m1000_mut0.2_minelite1|best_fit:16.0|best_it:6|time_to_best:0.02988|fevals_to_best:1609.0|fevals:1609.0,
#  ga_size16_pop400_m1000_mut0.1_minelite1|best_fit:16.0|best_it:4|time_to_best:0.04692|fevals_to_best:2407.0|fevals:2407.0,
#  ga_size16_pop400_m1000_mut0.2_minelite0|best_fit:16.0|best_it:5|time_to_best:0.24622|fevals_to_best:2808.0|fevals:2808.0,
#  ga_size16_pop400_m1000_mut0.1_minelite0|best_fit:16.0|best_it:6|time_to_best:0.3366|fevals_to_best:3209.0|fevals:3209.0,
#  ga_size16_pop400_m1000_mut0.3_minelite0|best_fit:16.0|best_it:3|time_to_best:0.04239|fevals_to_best:2006.0|fevals:2006.0,
#  ga_size16_pop400_m1000_mut0.3_minelite1|best_fit:16.0|best_it:3|time_to_best:0.03587|fevals_to_best:2006.0|fevals:2006.0,
#  ga_size16_pop800_m1000_mut0.1_minelite0|best_fit:16.0|best_it:2|time_to_best:0.06239|fevals_to_best:3205.0|fevals:3205.0,
#  ga_size16_pop800_m1000_mut0.2_minelite0|best_fit:16.0|best_it:3|time_to_best:0.08955|fevals_to_best:4006.0|fevals:4006.0,
#  ga_size16_pop800_m1000_mut0.3_minelite0|best_fit:16.0|best_it:3|time_to_best:0.09025|fevals_to_best:4006.0|fevals:4006.0,
#  ga_size16_pop800_m1000_mut0.1_minelite1|best_fit:16.0|best_it:4|time_to_best:0.1219|fevals_to_best:4807.0|fevals:4807.0,
#  ga_size16_pop800_m1000_mut0.2_minelite1|best_fit:16.0|best_it:4|time_to_best:0.12475|fevals_to_best:4807.0|fevals:4807.0,
#  ga_size32_pop100_m1000_mut0.3_minelite0|best_fit:32.0|best_it:10|time_to_best:0.01834|fevals_to_best:1217.0|fevals:1217.0,
#  ga_size32_pop100_m1000_mut0.3_minelite1|best_fit:32.0|best_it:12|time_to_best:0.02147|fevals_to_best:1419.0|fevals:1419.0,
#  ga_size32_pop100_m1000_mut0.1_minelite1|best_fit:32.0|best_it:15|time_to_best:0.02681|fevals_to_best:1723.0|fevals:1723.0,
#  ga_size32_pop100_m1000_mut0.1_minelite0|best_fit:32.0|best_it:10|time_to_best:0.03038|fevals_to_best:1216.0|fevals:1216.0,
#  ga_size32_pop100_m1000_mut0.2_minelite0|best_fit:32.0|best_it:13|time_to_best:0.04019|fevals_to_best:1522.0|fevals:1522.0,
#  ga_size32_pop100_m1000_mut0.2_minelite1|best_fit:32.0|best_it:12|time_to_best:0.0269|fevals_to_best:1419.0|fevals:1419.0,
#  ga_size16_pop800_m1000_mut0.3_minelite1|best_fit:16.0|best_it:3|time_to_best:0.08051|fevals_to_best:4006.0|fevals:4006.0,
#  ga_size32_pop200_m1000_mut0.2_minelite0|best_fit:32.0|best_it:9|time_to_best:0.03237|fevals_to_best:2217.0|fevals:2217.0,
#  ga_size32_pop200_m1000_mut0.3_minelite1|best_fit:32.0|best_it:13|time_to_best:0.0556|fevals_to_best:3021.0|fevals:3021.0,
#  ga_size32_pop200_m1000_mut0.1_minelite0|best_fit:32.0|best_it:10|time_to_best:0.05786|fevals_to_best:2419.0|fevals:2419.0,
#  ga_size32_pop200_m1000_mut0.3_minelite0|best_fit:32.0|best_it:12|time_to_best:0.07259|fevals_to_best:2821.0|fevals:2821.0,
#  ga_size32_pop200_m1000_mut0.1_minelite1|best_fit:32.0|best_it:13|time_to_best:0.06508|fevals_to_best:3022.0|fevals:3022.0,
#  ga_size32_pop200_m1000_mut0.2_minelite1|best_fit:32.0|best_it:13|time_to_best:0.0822|fevals_to_best:3022.0|fevals:3022.0,
#  ga_size32_pop400_m1000_mut0.1_minelite0|best_fit:32.0|best_it:11|time_to_best:0.40294|fevals_to_best:5218.0|fevals:5218.0,
#  ga_size32_pop400_m1000_mut0.1_minelite1|best_fit:32.0|best_it:9|time_to_best:0.08623|fevals_to_best:4415.0|fevals:4415.0,
#  ga_size32_pop400_m1000_mut0.2_minelite1|best_fit:32.0|best_it:12|time_to_best:0.1034|fevals_to_best:5618.0|fevals:5618.0,
#  ga_size32_pop400_m1000_mut0.3_minelite1|best_fit:32.0|best_it:11|time_to_best:0.10969|fevals_to_best:5218.0|fevals:5218.0,
#  ga_size32_pop400_m1000_mut0.3_minelite0|best_fit:32.0|best_it:11|time_to_best:0.09992|fevals_to_best:5218.0|fevals:5218.0,
#  ga_size32_pop400_m1000_mut0.2_minelite0|best_fit:32.0|best_it:10|time_to_best:0.12141|fevals_to_best:4817.0|fevals:4817.0,
#  ga_size32_pop800_m1000_mut0.1_minelite0|best_fit:32.0|best_it:9|time_to_best:0.55642|fevals_to_best:8815.0|fevals:8815.0,
#  ga_size32_pop800_m1000_mut0.1_minelite1|best_fit:32.0|best_it:12|time_to_best:0.80536|fevals_to_best:11220.0|fevals:11220.0,
#  ga_size32_pop800_m1000_mut0.3_minelite0|best_fit:32.0|best_it:10|time_to_best:0.18431|fevals_to_best:9618.0|fevals:9618.0,
#  ga_size32_pop800_m1000_mut0.2_minelite1|best_fit:32.0|best_it:10|time_to_best:0.17486|fevals_to_best:9616.0|fevals:9616.0,
#  ga_size32_pop800_m1000_mut0.3_minelite1|best_fit:32.0|best_it:10|time_to_best:0.18408|fevals_to_best:9618.0|fevals:9618.0,
#  ga_size32_pop800_m1000_mut0.2_minelite0|best_fit:32.0|best_it:12|time_to_best:0.21209|fevals_to_best:11219.0|fevals:11219.0]

# %%
rhc = Experiment.pickle_load(os.path.join(mlr_data, 'onemax','pickle_rhc.p'))
#graph it. 
s = Search()
s.filters.append(TagFilter('size',32))
graph_generate_single(rhc, search=s)
rhc.results
# Out:
# [rhc_size1_r5_m1000|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  rhc_size2_r1_m1000|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  rhc_size1_r1_m1000|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  rhc_size1_r2_m1000|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  rhc_size1_r10_m1000|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  rhc_size1_r20_m1000|best_fit:1.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  rhc_size2_r2_m1000|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  rhc_size2_r10_m1000|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  rhc_size4_r1_m1000|best_fit:4.0|best_it:2|time_to_best:0.00022|fevals_to_best:6.0|fevals:6.0,
#  rhc_size4_r10_m1000|best_fit:4.0|best_it:2|time_to_best:0.00274|fevals_to_best:6.0|fevals:6.0,
#  rhc_size4_r5_m1000|best_fit:4.0|best_it:2|time_to_best:0.0004|fevals_to_best:6.0|fevals:6.0,
#  rhc_size2_r5_m1000|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  rhc_size4_r2_m1000|best_fit:4.0|best_it:2|time_to_best:0.00042|fevals_to_best:6.0|fevals:6.0,
#  rhc_size2_r20_m1000|best_fit:2.0|best_it:0|time_to_best:0.0|fevals_to_best:2.0|fevals:2.0,
#  rhc_size8_r10_m1000|best_fit:8.0|best_it:23|time_to_best:0.00394|fevals_to_best:30.0|fevals:30.0,
#  rhc_size8_r5_m1000|best_fit:8.0|best_it:23|time_to_best:0.0019|fevals_to_best:30.0|fevals:30.0,
#  rhc_size8_r20_m1000|best_fit:8.0|best_it:23|time_to_best:0.01269|fevals_to_best:30.0|fevals:30.0,
#  rhc_size4_r20_m1000|best_fit:4.0|best_it:2|time_to_best:0.00657|fevals_to_best:6.0|fevals:6.0,
#  rhc_size8_r1_m1000|best_fit:8.0|best_it:23|time_to_best:0.00062|fevals_to_best:30.0|fevals:30.0,
#  rhc_size8_r2_m1000|best_fit:8.0|best_it:23|time_to_best:0.00077|fevals_to_best:30.0|fevals:30.0,
#  rhc_size16_r1_m1000|best_fit:16.0|best_it:38|time_to_best:0.00104|fevals_to_best:51.0|fevals:51.0,
#  rhc_size16_r2_m1000|best_fit:16.0|best_it:38|time_to_best:0.00258|fevals_to_best:51.0|fevals:51.0,
#  rhc_size16_r5_m1000|best_fit:16.0|best_it:38|time_to_best:0.05737|fevals_to_best:51.0|fevals:51.0,
#  rhc_size32_r2_m1000|best_fit:32.0|best_it:114|time_to_best:0.0156|fevals_to_best:131.0|fevals:131.0,
#  rhc_size32_r1_m1000|best_fit:32.0|best_it:114|time_to_best:0.00492|fevals_to_best:131.0|fevals:131.0,
#  rhc_size16_r20_m1000|best_fit:16.0|best_it:38|time_to_best:0.27837|fevals_to_best:51.0|fevals:51.0,
#  rhc_size16_r10_m1000|best_fit:16.0|best_it:38|time_to_best:0.06702|fevals_to_best:51.0|fevals:51.0,
#  rhc_size32_r5_m1000|best_fit:32.0|best_it:114|time_to_best:0.14078|fevals_to_best:131.0|fevals:131.0,
#  rhc_size32_r10_m1000|best_fit:32.0|best_it:114|time_to_best:0.12862|fevals_to_best:131.0|fevals:131.0,
#  rhc_size32_r20_m1000|best_fit:32.0|best_it:114|time_to_best:0.39338|fevals_to_best:131.0|fevals:131.0]
